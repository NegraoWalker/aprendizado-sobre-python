# %% [markdown]
# ## Tipos de dados:
# ### int, float, string, boolean

# %%
idade = 32 #int
print(idade)

# %%
faturamento = 125000.00 #float
print(faturamento)

# %%
nome = "Walker" #string
print(nome)

# %%
homem = True #boolean
print(homem)
